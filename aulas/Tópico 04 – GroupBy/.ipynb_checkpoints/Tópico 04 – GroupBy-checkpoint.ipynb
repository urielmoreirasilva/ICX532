# %% [raw]
# ---
# layout: default
# title: "Tópico 04 – Mais Consultas e GroupBy"
# parent: "Aulas"
# nav_order: 4
# ---

# %% [markdown]
# # Tópico 04 – Mais Consultas e GroupBy [<img src="images/colag_logo.svg" style="float: right; vertical-align: middle; width: 42px; height: 42px;">](https://colab.research.google.com/github/urielmoreirasilva/urielmoreirasilva.github.io/blob/main/aulas/T%C3%B3pico%2004/04%20%E2%80%93%20GroupBy.ipynb) [<img src="images/github_logo.svg" style="float: right; margin-right: 12px; vertical-align: middle; width: 36px; height: 36px;">](https://github.com/urielmoreirasilva/urielmoreirasilva.github.io/blob/main/aulas/T%C3%B3pico%2004/04%20%E2%80%93%20GroupBy.ipynb)
#
# Vamos aprender a agrupar e a sumarizar dados!
#
# ### Resultados Esperados
# 1. Aprender a utilizar a função `groupby`.
# 1. Aprender mais sobre o potencial do `pandas`!
#
# ### Referências
# - [BPD, Capítulos 10 a 11](https://notes.dsc10.com/)
# - [CIT, Capítulo 6](https://inferentialthinking.com/)
#
# Material adaptado do [DSC10 (UCSD)](https://dsc10.com/) por [Flavio Figueiredo (DCC-UFMG)](https://flaviovdf.io/fcd/) e [Uriel Silva (DEST-UFMG)](https://urielmoreirasilva.github.io)

# %%
# Importando BabyPandas e Numpy
import babypandas as bpd
import numpy as np

# %%
# Importando uma nova biblioteca: Matplotlib!
# Utilizaremos essa biblioteca para fazer gráficos
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ### Sobre os dados: Ainda estamos na feira da Afonso Pena
#
# O DataFrame `afonso_pena` abaixo contém os dados dos feirantes da Afonso Pena:

# %%
# Carregando o DataFrame
afonso_pena = bpd.read_csv('data/afonso_pena.csv')

# Calculando a densidade produtos/área de cada barraca
produtos = afonso_pena.get('NUMERO_PRODUTOS_CADASTRADOS')
area = afonso_pena.get('AREA')
afonso_pena = afonso_pena.assign(
    DENSIDADE = produtos / area
)

# Atribuindo um índice a cada uma das linhas
afonso_pena = afonso_pena.set_index('ID_FEIRA_AFONSO_PENA_BARRACA')
afonso_pena
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             F.F2.V016
# 84                             G.F3.V052
# 85                             E.F4.V003
# 86                             E.F2.V004
# 87                             D.F2.V016
# ...                                  ...
# 1350                           G.F4.V014
# 1351                           J.F1.V004
# 1352                           D.F4.V050
# 1353                           G.F2.V010
# 1354                           G.F1.V061
#
#                                                            NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              BARRACA CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  BARRACA CECÍLIA PAGANO NEVES SALAZAR
# 87                                      BARRACA CÉLIA APARECIDA DE SOUZA
# ...                                                                  ...
# 1350                                          BARRACA HELCIO LICIO SILVA
# 1351                                       BARRACA DIEGO DOS SANTOS DIAS
# 1352                                                 BARRACA JAIR CORREA
# 1353                               BARRACA SIDNEY FERNANDO KNEIPP SOARES
# 1354                                      BARRACA REGINA GARCIA FERREIRA
#
#                                                    NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  CECÍLIA PAGANO NEVES SALAZAR
# 87                                      CÉLIA APARECIDA DE SOUZA
# ...                                                          ...
# 1350                                          HELCIO LICIO SILVA
# 1351                                       DIEGO DOS SANTOS DIAS
# 1352                                                 JAIR CORREA
# 1353                               SIDNEY FERNANDO KNEIPP SOARES
# 1354                                      REGINA GARCIA FERREIRA
#
#                                                    NOME_PREPOSTO  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                           JANA FONSECA VIEIRA
# 84                                    KARINA RODRIGUES BRANDORFI
# 85                            BARBARA ISABELLE CARVALHO DE PAULA
# 86                                   GISELE PAGANO NEVES SALAZAR
# 87                                          EDSON PIRES DE SOUZA
# ...                                                          ...
# 1350                             GRAZIELA CRISTINA RAMALHO SILVA
# 1351                                     CELSO DE SOUZA LINHARES
# 1352                               Keli Aparecida Batista Correa
# 1353                                 ANA PAULA FAUSTINA DE SOUZA
# 1354                             Rejane Garcia Ferreira Clemente
#
#                                       NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                       Criança
# 84                                   Bijouterias
# 85                            Vestuário Infantil
# 86                            Vestuário Infantil
# 87                                     Vestuário
# ...                                          ...
# 1350                                 Bijouterias
# 1351                                    Calçados
# 1352                                   Vestuário
# 1353                                 Bijouterias
# 1354                                 Bijouterias
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# 84                                          BRINCO, ANEL, PULSEIRA, COLAR, ARCO
# 85                                                   VESTIDO, CONJUNTO, MACACÃO
# 86                                                    MACACÃO, BLUSA, SAPATINHO
# 87                            BLUSA, BERMUDA, ROUPA DE GINÁSTICA, SAIA, VEST...
# ...                                                                         ...
# 1350                          ANEL, COLAR, BROCHE, BRINCO, PULSEIRA, ALIANÇA...
# 1351                                              RASTEIRINHA, SAPATO, SANDÁLIA
# 1352                          VESTIDO DE MALHA, BATA DE TECIDO, CONJUNTO, SA...
# 1353                          COLAR, GARGANTILHA, ARCO, ANEL, PASSADOR DE CA...
# 1354                          COLAR DE METAL, PRESILHA, PASSADOR DE CABELO, ...
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                                    5.0  11.838911
# 84                                                    5.0  11.838911
# 85                                                    3.0  11.838911
# 86                                                    3.0  11.827592
# 87                                                    7.0  11.827592
# ...                                                   ...        ...
# 1350                                                  7.0  11.838911
# 1351                                                  3.0  11.827592
# 1352                                                  5.0  11.827592
# 1353                                                  7.0  11.838911
# 1354                                                  4.0  11.827592
#
#                               DENSIDADE
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             0.422336
# 84                             0.422336
# 85                             0.253402
# 86                             0.253644
# 87                             0.591836
# ...                                 ...
# 1350                           0.591271
# 1351                           0.253644
# 1352                           0.422740
# 1353                           0.591271
# 1354                           0.338192
#
# [1250 rows x 9 columns]

# %% [markdown]
# ## Qual o número total de barracas de comida? 🍴

# %% [markdown]
# ### Consultando as _linhas_ de um DataFrame
#
# - **Pergunta:** Como podemos encontrar o _número total_ de linhas de um DataFrame que satisfaçam uma certa condição? 🤔
#
# - **Resposta:** Podemos proceder assim:
#     1. Realize uma consulta para extrair um DataFrame cujo `'NOME_SETOR'` seja igual a `'Alimentação'`.
#     1. Extraia o primeiro elemento `[0]` do método `.shape` aplicado ao DataFrame anterior.

# %%
comida = afonso_pena[afonso_pena.get('NOME_SETOR') == 'Alimentação']
comida.shape[0]
# Out:
# 100

# %% [markdown]
# ## Qual o vendedor que vende mais produtos de comida?

# %% [markdown]
# ## Consultando um _elemento específico_ de um DataFrame
#
# - **Pergunta:** Como podemos encontrar uma _linha específica_ em um DataFrame que satisfaça uma certa condição? 🤔
#
# - **Resposta:** Podemos proceder de maneira análoga à pergunta anterior, com alguns passos extras:
#     1. Realize uma consulta para extrair um DataFrame cujo `'NOME_SETOR'` seja igual a `'Alimentação'`.
#     1. Ordene as linhas do DataFrame resultante por `'NUMERO_PRODUTOS_CADASTRADOS'`, em ordem decrescente.
#     1. Extraia o primeiro elemento `[0]` da coluna `'NOME_FEIRANTE'`, utilizando o método `.iloc`.

# %%
comida = comida.sort_values(by = 'NUMERO_PRODUTOS_CADASTRADOS', ascending = False)
comida
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 109                            Y.F1.V012
# 1406                           Z.F1.V007
# 1015                           X.F1.V020
# 380                            Y.F1.V020
# 26                             Y.F2.V007
# ...                                  ...
# 1269                           X.F2.V013
# 1457                           X.F2.V011
# 1423                           X.F1.V003
# 261                            X.F2.V003
# 92                             Y.F1.V003
#
#                                                                   NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 109                                                BARRACA DAYSE PINTO NORBERTO
# 1406                          BARRACA FRANCINERE AMARAL CARDOSO RIBEIRO DE S...
# 1015                                      BARRACA VERA LUIZA DE CARVALHO MACEDO
# 380                                       BARRACA MARGARET LÚCIA DA COSTA SILVA
# 26                                                   BARRACA ANA CALDEIRA GOMES
# ...                                                                         ...
# 1269                                     BARRACA FELIPE RODRIGUES ALVES DE DEUS
# 1457                                           BARRACA WELLINGTON ALVES DE DEUS
# 1423                                  BARRACA CELIA APARECIDA MONTEIRO CIPRIANO
# 261                                       BARRACA JOÃO GERALDO MARTINS DE SOUZA
# 92                                         BARRACA CHAQUIBE HASSAN SOUKI HUNIOR
#
#                                                            NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 109                                                 DAYSE PINTO NORBERTO
# 1406                          FRANCINERE AMARAL CARDOSO RIBEIRO DE SOUZA
# 1015                                       VERA LUIZA DE CARVALHO MACEDO
# 380                                        MARGARET LÚCIA DA COSTA SILVA
# 26                                                    ANA CALDEIRA GOMES
# ...                                                                  ...
# 1269                                      FELIPE RODRIGUES ALVES DE DEUS
# 1457                                            WELLINGTON ALVES DE DEUS
# 1423                                   CELIA APARECIDA MONTEIRO CIPRIANO
# 261                                        JOÃO GERALDO MARTINS DE SOUZA
# 92                                          CHAQUIBE HASSAN SOUKI HUNIOR
#
#                                                  NOME_PREPOSTO   NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 109                                  DJALMA ANTÔNIO DE FREITAS  Alimentação
# 1406                                   RAYKARD AGUIAR DE JESUS  Alimentação
# 1015                                         ORLANDINEIA ALVES  Alimentação
# 380                            MARIA TRINDADE DECIOLA DE JESUS  Alimentação
# 26                            PAULO HENRIQUE DE JESUS CALDEIRA  Alimentação
# ...                                                        ...          ...
# 1269                                      SIDNEY ALVES DE DEUS  Alimentação
# 1457                                      SANDRO ALVES DE DEUS  Alimentação
# 1423                                 APARECIDA SANTOS MONTEIRO  Alimentação
# 261                              CHARLES DAVIDSON ROSA MARTINS  Alimentação
# 92                                           GISMAR JOSÉ GOMES  Alimentação
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 109                           CERVEJA, TORRESMO, CHIPS, AZEITONA, REFRIGERAN...
# 1406                          CERVEJA, REFRIGERANTE, SUCO INDUSTRIALIZADO, E...
# 1015                          CERVEJA, SANDUÍCHE NATURAL, BISCOITO, BOLO, RO...
# 380                           ACARAJÉ, BOLINHO DE CARNE DE SOL, SUCO DE AÇAÍ...
# 26                            CHURRASCO, PÃO DE QUEIJO, LEITE, REFRIGERANTE,...
# ...                                                                         ...
# 1269                                                                  CHURRASCO
# 1457                                                                  CHURRASCO
# 1423                                                                    ACARAJÉ
# 261                                                                   CHURRASCO
# 92                                                                 DOCE DIVERSO
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 109                                                  21.0  33.611057
# 1406                                                 20.0  33.611058
# 1015                                                 17.0  33.595966
# 380                                                  16.0  33.539371
# 26                                                   14.0  33.611058
# ...                                                   ...        ...
# 1269                                                  1.0  33.558728
# 1457                                                  1.0  33.595966
# 1423                                                  1.0  33.697508
# 261                                                   1.0  33.569063
# 92                                                    1.0  33.605972
#
#                               DENSIDADE
# ID_FEIRA_AFONSO_PENA_BARRACA
# 109                            0.624794
# 1406                           0.595042
# 1015                           0.506013
# 380                            0.477051
# 26                             0.416530
# ...                                 ...
# 1269                           0.029799
# 1457                           0.029765
# 1423                           0.029676
# 261                            0.029789
# 92                             0.029757
#
# [100 rows x 9 columns]

# %%
comida.get('NOME_FEIRANTE').iloc[0]
# Out:
# 'DAYSE PINTO NORBERTO'

# %% [markdown]
# - O método `.iloc` retorna a n-ésima linha do `DataFrame` (ou `Series`)  correspondente.
# - Note que `.iloc` não busca por _índice_, mas sim por _linha_.

# %% [markdown]
# Observe que podemos obter o mesmo resultado acima ordenando o DataFrame de maneira _decrescente_ e utilizando o método `.iloc` para obter o _último_ elemento do DataFrame resultante:

# %%
comida = comida.sort_values(by = 'NUMERO_PRODUTOS_CADASTRADOS', ascending = True)
comida.get('NOME_FEIRANTE').iloc[-1]
# Out:
# 'DAYSE PINTO NORBERTO'

# %% [markdown]
# ### E se nenhuma condição for satisfeita?
#
# - Quando nenhuma condição da nossa consulta é satisfeita, o resultado ainda é um `DataFrame`, mas com 0 linhas:

# %%
afonso_pena[afonso_pena.get('NOME_FEIRANTE') == 'BABY PANDAS']
# Out:
# Empty DataFrame
# Columns: [CODIGO_VAGA, NOME_FANTASIA, NOME_FEIRANTE, NOME_PREPOSTO, NOME_SETOR, PRODUTOS, NUMERO_PRODUTOS_CADASTRADOS, AREA, DENSIDADE]
# Index: []

# %%
type(afonso_pena[afonso_pena.get('NOME_FEIRANTE') == 'BABY PANDAS'])
# Out:
# babypandas.bpd.DataFrame

# %%
afonso_pena[afonso_pena.get('NOME_FEIRANTE') == 'BABY PANDAS'].shape[0]
# Out:
# 0

# %% [markdown]
# ### Exercício ✅
#
# Qual expressão abaixo possui como resultado o número total de **produtos** para crianças?
#
# A. `afonso_pena[afonso_pena.get('NOME_SETOR') == 'Criança'].shape`
#
# B. `afonso_pena[afonso_pena.get('NOME_SETOR') == 'Criança'].get('NUMERO_PRODUTOS_CADASTRADOS').sum()`
#
# C.`afonso_pena[afonso_pena.get('NOME_SETOR') != 'Criança'].get('NUMERO_PRODUTOS_CADASTRADOS').sum()`
#
# D. Mais de um dos itens acima.

# %% [markdown]
# ### Exercício ✅
#
# **Pergunta**: Quais são os produtos vendidos pelo feirante que mais vende produtos para crianças?
#
# Escreva abaixo uma linha de código que avalie a resposta.

# %%
...
# Out:
# Ellipsis

# %% [markdown]
# ## Quantos feirantes vendem "roupas para crianças" _ou_ "produtos para crianças"?

# %% [markdown]
# ### Consultas com múltiplas condições
#
# - **Pergunta:** Como podemos filtrar um DataFrame de acordo com múltiplas condições? 🤔
#
# - **Resposta:** Basta proceder de maneira análoga ao que fazemos com uma consulta simples, bastando apenas prestar atenção à alguns pequenos detalhes extras:
#     - Para escrever uma consulta com múltiplas condições, use `&` para "e" e `|` para "ou".
#     - **Você deve sempre usar parênteses `( )` em torno de cada condição!**

# %%
afonso_pena[(afonso_pena.get('NOME_SETOR') == 'Vestuário Infantil') | (afonso_pena.get('NOME_SETOR') == 'Criança')]
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             F.F2.V016
# 85                             E.F4.V003
# 86                             E.F2.V004
# 88                             E.F3.V016
# 94                             E.F4.V029
# ...                                  ...
# 1426                           F.F3.V010
# 1435                           E.F4.V006
# 1337                           F.F2.V004
# 1342                           E.F1.V005
# 1343                           E.F1.V033
#
#                                                                   NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                     BARRACA CARMEN EMMANUEL DOS SANTOS SILVA
# 85                                     BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                         BARRACA CECÍLIA PAGANO NEVES SALAZAR
# 88                                        BARRACA CELINA MARIA  SILVA MARCELINO
# 94                            BARRACA CLARICE CONCEIÇÃO DAS GRAÇAS DE OLIVEI...
# ...                                                                         ...
# 1426                                           BARRACA ALESSANDRA DE ABREU REIS
# 1435                                              BARRACA CILDA LUZIA GUALBERTO
# 1337                                      BARRACA MATHEUS PESSALI TIAGO BARBOSA
# 1342                                           BARRACA MAIRA FERNANDES DE MOURA
# 1343                                               BARRACA ELIANE CORREA JANSEN
#
#                                                               NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                         CARMEN EMMANUEL DOS SANTOS SILVA
# 85                                         CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                             CECÍLIA PAGANO NEVES SALAZAR
# 88                                            CELINA MARIA  SILVA MARCELINO
# 94                            CLARICE CONCEIÇÃO DAS GRAÇAS DE OLIVEIRA LIMA
# ...                                                                     ...
# 1426                                               ALESSANDRA DE ABREU REIS
# 1435                                                  CILDA LUZIA GUALBERTO
# 1337                                          MATHEUS PESSALI TIAGO BARBOSA
# 1342                                               MAIRA FERNANDES DE MOURA
# 1343                                                   ELIANE CORREA JANSEN
#
#                                                    NOME_PREPOSTO  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                           JANA FONSECA VIEIRA
# 85                            BARBARA ISABELLE CARVALHO DE PAULA
# 86                                   GISELE PAGANO NEVES SALAZAR
# 88                                    ALBERTINO SERGIO MARCELINO
# 94                               ANGELICA MARIA DE OLIVEIRA LIMA
# ...                                                          ...
# 1426                             GLAUCIA HELENA DE ABREU TAVARES
# 1435                           CILMA MARIA GUALBERTO DE OLIVEIRA
# 1337                                       MIRNA COSTA GONÇALVES
# 1342                                   MAURÍCIO MARTINS TERRINHA
# 1343                                        ANDREA CORREA JANSEN
#
#                                       NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                       Criança
# 85                            Vestuário Infantil
# 86                            Vestuário Infantil
# 88                            Vestuário Infantil
# 94                            Vestuário Infantil
# ...                                          ...
# 1426                                     Criança
# 1435                          Vestuário Infantil
# 1337                                     Criança
# 1342                          Vestuário Infantil
# 1343                          Vestuário Infantil
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# 85                                                   VESTIDO, CONJUNTO, MACACÃO
# 86                                                    MACACÃO, BLUSA, SAPATINHO
# 88                              FANTASIA, BERMUDA, CALÇA, SAIA, VESTIDO, CAMISA
# 94                            CONJUNTO, SHORT, CUECA, CAMISA, CAMISETA, BLUS...
# ...                                                                         ...
# 1426                          ACESSÓRIOS PARA CACHORRO, ALMOFADA, CAMA DE TE...
# 1435                               VESTIDO, BOLERO, CUECA, BERMUDA, SAIA, BLUSA
# 1337                          QUADRO, TOALHA FRALDA, TOALHA, BRINQUEDO PEDAG...
# 1342                                    JARDINEIRA, VESTIDO, SHORT, SAIA, BLUSA
# 1343                               VESTIDO, TIARA, BLUSA, BODY, TOUCA, CALCINHA
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                                    5.0  11.838911
# 85                                                    3.0  11.838911
# 86                                                    3.0  11.827592
# 88                                                    6.0  11.827592
# 94                                                    7.0  11.838911
# ...                                                   ...        ...
# 1426                                                 14.0  11.838911
# 1435                                                  6.0  11.827592
# 1337                                                  6.0  11.838911
# 1342                                                  5.0  11.838911
# 1343                                                  6.0  11.838911
#
#                               DENSIDADE
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             0.422336
# 85                             0.253402
# 86                             0.253644
# 88                             0.507288
# 94                             0.591271
# ...                                 ...
# 1426                           1.182541
# 1435                           0.507288
# 1337                           0.506803
# 1342                           0.422336
# 1343                           0.506803
#
# [224 rows x 9 columns]

# %%
# Nota: dentro de parênteses () ou colchetes [], podemos quebrar a linha!
# Isso nos ajuda na leitura do código
afonso_pena[(afonso_pena.get('NOME_SETOR') == 'Vestuário Infantil') | 
   (afonso_pena.get('NOME_SETOR') == 'Criança')]
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             F.F2.V016
# 85                             E.F4.V003
# 86                             E.F2.V004
# 88                             E.F3.V016
# 94                             E.F4.V029
# ...                                  ...
# 1426                           F.F3.V010
# 1435                           E.F4.V006
# 1337                           F.F2.V004
# 1342                           E.F1.V005
# 1343                           E.F1.V033
#
#                                                                   NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                     BARRACA CARMEN EMMANUEL DOS SANTOS SILVA
# 85                                     BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                         BARRACA CECÍLIA PAGANO NEVES SALAZAR
# 88                                        BARRACA CELINA MARIA  SILVA MARCELINO
# 94                            BARRACA CLARICE CONCEIÇÃO DAS GRAÇAS DE OLIVEI...
# ...                                                                         ...
# 1426                                           BARRACA ALESSANDRA DE ABREU REIS
# 1435                                              BARRACA CILDA LUZIA GUALBERTO
# 1337                                      BARRACA MATHEUS PESSALI TIAGO BARBOSA
# 1342                                           BARRACA MAIRA FERNANDES DE MOURA
# 1343                                               BARRACA ELIANE CORREA JANSEN
#
#                                                               NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                         CARMEN EMMANUEL DOS SANTOS SILVA
# 85                                         CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                             CECÍLIA PAGANO NEVES SALAZAR
# 88                                            CELINA MARIA  SILVA MARCELINO
# 94                            CLARICE CONCEIÇÃO DAS GRAÇAS DE OLIVEIRA LIMA
# ...                                                                     ...
# 1426                                               ALESSANDRA DE ABREU REIS
# 1435                                                  CILDA LUZIA GUALBERTO
# 1337                                          MATHEUS PESSALI TIAGO BARBOSA
# 1342                                               MAIRA FERNANDES DE MOURA
# 1343                                                   ELIANE CORREA JANSEN
#
#                                                    NOME_PREPOSTO  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                           JANA FONSECA VIEIRA
# 85                            BARBARA ISABELLE CARVALHO DE PAULA
# 86                                   GISELE PAGANO NEVES SALAZAR
# 88                                    ALBERTINO SERGIO MARCELINO
# 94                               ANGELICA MARIA DE OLIVEIRA LIMA
# ...                                                          ...
# 1426                             GLAUCIA HELENA DE ABREU TAVARES
# 1435                           CILMA MARIA GUALBERTO DE OLIVEIRA
# 1337                                       MIRNA COSTA GONÇALVES
# 1342                                   MAURÍCIO MARTINS TERRINHA
# 1343                                        ANDREA CORREA JANSEN
#
#                                       NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                       Criança
# 85                            Vestuário Infantil
# 86                            Vestuário Infantil
# 88                            Vestuário Infantil
# 94                            Vestuário Infantil
# ...                                          ...
# 1426                                     Criança
# 1435                          Vestuário Infantil
# 1337                                     Criança
# 1342                          Vestuário Infantil
# 1343                          Vestuário Infantil
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# 85                                                   VESTIDO, CONJUNTO, MACACÃO
# 86                                                    MACACÃO, BLUSA, SAPATINHO
# 88                              FANTASIA, BERMUDA, CALÇA, SAIA, VESTIDO, CAMISA
# 94                            CONJUNTO, SHORT, CUECA, CAMISA, CAMISETA, BLUS...
# ...                                                                         ...
# 1426                          ACESSÓRIOS PARA CACHORRO, ALMOFADA, CAMA DE TE...
# 1435                               VESTIDO, BOLERO, CUECA, BERMUDA, SAIA, BLUSA
# 1337                          QUADRO, TOALHA FRALDA, TOALHA, BRINQUEDO PEDAG...
# 1342                                    JARDINEIRA, VESTIDO, SHORT, SAIA, BLUSA
# 1343                               VESTIDO, TIARA, BLUSA, BODY, TOUCA, CALCINHA
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                                    5.0  11.838911
# 85                                                    3.0  11.838911
# 86                                                    3.0  11.827592
# 88                                                    6.0  11.827592
# 94                                                    7.0  11.838911
# ...                                                   ...        ...
# 1426                                                 14.0  11.838911
# 1435                                                  6.0  11.827592
# 1337                                                  6.0  11.838911
# 1342                                                  5.0  11.838911
# 1343                                                  6.0  11.838911
#
#                               DENSIDADE
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             0.422336
# 85                             0.253402
# 86                             0.253644
# 88                             0.507288
# 94                             0.591271
# ...                                 ...
# 1426                           1.182541
# 1435                           0.507288
# 1337                           0.506803
# 1342                           0.422336
# 1343                           0.506803
#
# [224 rows x 9 columns]

# %%
afonso_pena[(afonso_pena.get('NOME_SETOR') == 'Vestuário Infantil') | (afonso_pena.get('NOME_SETOR') == 'Criança')].shape[0]
# Out:
# 224

# %% [markdown]
# ⚠️ **Nota**: Não utilize as palavras-chave Python `and` e `or` aqui! Eles não se comportam como você esperaria.

# %%
afonso_pena[(afonso_pena.get('NOME_SETOR') == 'Vestuário Infantil') or (afonso_pena.get('NOME_SETOR') == 'Criança')].shape[0]
# Out:
# 121

# %% [markdown]
# - Uma maneira de verificarmos quantas condições válidas existem para uma certa coluna é utilizar o método `.unique` para verificar quantos valores _únicos_ as linhas dessa coluna assumem:

# %%
afonso_pena.get('NOME_SETOR').unique()
# Out:
# array(['Criança', 'Bijouterias', 'Vestuário Infantil', 'Vestuário',
#        'Calçados', 'Alimentação', 'Cintos, Bolsas e Acessórios',
#        'Artes e Pintura', 'Arranjos e Complementos',
#        'Decoração e Utilidades', 'Cama, Mesa, Banho e Tapeçaria',
#        'Mobilário, Flores, Arranjos, Cestaria', 'Esculturas'],
#       dtype=object)

# %% [markdown]
# ### Exercício ✅
#
# Cada uma das perguntas a seguir pode ser respondida consultando o DataFrame `afonso_pena`:
#
# 1. Quantos feirantes vendem 'Vestuário'?
# 1. Qual o nome do feirante que mais vende 'Vestuário'?
# 1. Qual categoria têm mais produtos: 'Artes e Pintura' ou 'Esculturas'?
#
# Tente escrever um código abaixo para responder a cada pergunta.

# %%
...
# Out:
# Ellipsis

# %%
...
# Out:
# Ellipsis

# %%
...
# Out:
# Ellipsis

# %% [markdown]
# ### Selecionando linhas por _posição_: o método `.take`
#
# - As consultas nos permitem selecionar linhas que satisfaçam uma determinada _condição_.
# - Porém, às vezes podemos estar interessados em selecionar linhas _posições_ específicas do DataFrame.
# - Fazemos isso com `.take([list_of_integer_positions])`, onde `list_of_integer_positions` são os índices das linhas nas quais estamos interessados.
# - O método `.take` nos retorna apenas as linhas cujas posições estão na lista especificada, e logo é análogo a usar `.iloc[]` em uma série.

# %%
afonso_pena.take([1, 3, 5])
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 84                             G.F3.V052
# 86                             E.F2.V004
# 88                             E.F3.V016
#
#                                                            NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 84                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARA
# 86                                  BARRACA CECÍLIA PAGANO NEVES SALAZAR
# 88                                 BARRACA CELINA MARIA  SILVA MARCELINO
#
#                                                    NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 84                            CARMEN FERNANDA ROCHA DE ALCANTARA
# 86                                  CECÍLIA PAGANO NEVES SALAZAR
# 88                                 CELINA MARIA  SILVA MARCELINO
#
#                                             NOME_PREPOSTO          NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 84                             KARINA RODRIGUES BRANDORFI         Bijouterias
# 86                            GISELE PAGANO NEVES SALAZAR  Vestuário Infantil
# 88                             ALBERTINO SERGIO MARCELINO  Vestuário Infantil
#
#                                                                      PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 84                                        BRINCO, ANEL, PULSEIRA, COLAR, ARCO
# 86                                                  MACACÃO, BLUSA, SAPATINHO
# 88                            FANTASIA, BERMUDA, CALÇA, SAIA, VESTIDO, CAMISA
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 84                                                    5.0  11.838911
# 86                                                    3.0  11.827592
# 88                                                    6.0  11.827592
#
#                               DENSIDADE
# ID_FEIRA_AFONSO_PENA_BARRACA
# 84                             0.422336
# 86                             0.253644
# 88                             0.507288

# %% [markdown]
# Podemos também utilizar `.take` junto com intervalos!

# %%
afonso_pena.take(np.arange(5))
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             F.F2.V016
# 84                             G.F3.V052
# 85                             E.F4.V003
# 86                             E.F2.V004
# 87                             D.F2.V016
#
#                                                            NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              BARRACA CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  BARRACA CECÍLIA PAGANO NEVES SALAZAR
# 87                                      BARRACA CÉLIA APARECIDA DE SOUZA
#
#                                                    NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  CECÍLIA PAGANO NEVES SALAZAR
# 87                                      CÉLIA APARECIDA DE SOUZA
#
#                                                    NOME_PREPOSTO  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                           JANA FONSECA VIEIRA
# 84                                    KARINA RODRIGUES BRANDORFI
# 85                            BARBARA ISABELLE CARVALHO DE PAULA
# 86                                   GISELE PAGANO NEVES SALAZAR
# 87                                          EDSON PIRES DE SOUZA
#
#                                       NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                       Criança
# 84                                   Bijouterias
# 85                            Vestuário Infantil
# 86                            Vestuário Infantil
# 87                                     Vestuário
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# 84                                          BRINCO, ANEL, PULSEIRA, COLAR, ARCO
# 85                                                   VESTIDO, CONJUNTO, MACACÃO
# 86                                                    MACACÃO, BLUSA, SAPATINHO
# 87                            BLUSA, BERMUDA, ROUPA DE GINÁSTICA, SAIA, VEST...
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                                    5.0  11.838911
# 84                                                    5.0  11.838911
# 85                                                    3.0  11.838911
# 86                                                    3.0  11.827592
# 87                                                    7.0  11.827592
#
#                               DENSIDADE
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             0.422336
# 84                             0.422336
# 85                             0.253402
# 86                             0.253644
# 87                             0.591836

# %% [markdown]
# ## Qual é área total de cada setor?

# %% [markdown]
# ### Agrupamentos por colunas
#
# - **Pergunta:** Como podemos agrupar um DataFrame de acordo com certas condições? 🤔
#
# - **Resposta:** Uma maneira simples e direta é filtrar o DataFrame de acordo com a condição especificada, e depois utilizar alguma função para resumir as informações contidas nas linhas correspondentes (como por exemplo `.count`, `.sum`, `.mean`, `.min`, `.max`, `.median`).

# %% [markdown]
# No nosso exemplo, para encontrar a área total do setor correspondente aos produtos de crianças, basta fazer:

# %%
afonso_pena[afonso_pena.get('NOME_SETOR') == 'Criança'].get('AREA').sum()
# Out:
# 1274.9974161428677

# %% [markdown]
# Por outro lado, se quisermos a área total correspondente aos produtos relacionados à vestuário infantil, fazemos:

# %%
afonso_pena[afonso_pena.get('NOME_SETOR') == 'Vestuário Infantil'].get('AREA').sum()
# Out:
# 1431.87438966735

# %% [markdown]
# - Apesar de resolver nosso problema parcialmente, essa abordagem é bem ineficiente!
# - Aqui temos que gravar o nome de cada setor, e escrever no mínimo uma linha de código para cada um.
# - Se tivermos um grande número de setores, copiar e colar muitas vezes não é muito prático, e geralmente é uma fonte adicional de erros no código.

# %% [markdown]
# ### GroupBy: dividir, agregar e combinar
#
# Podemos utilizar o método `.groupby` para responder à nossa pergunta anterior com apenas uma linha de código:

# %%
# Descomente as 2 linhas abaixo caso você queira ver todas as linhas do DataFrame
# import pandas as pd
# pd.set_option("display.max_rows", 20)
afonso_pena.groupby('NOME_SETOR').sum()
# Out:
#                                        NUMERO_PRODUTOS_CADASTRADOS  \
# NOME_SETOR
# Alimentação                                                  733.0
# Arranjos e Complementos                                      379.0
# Artes e Pintura                                               62.0
# Bijouterias                                                 1047.0
# Calçados                                                     774.0
# ...                                                            ...
# Decoração e Utilidades                                       423.0
# Esculturas                                                     6.0
# Mobilário, Flores, Arranjos, Cestaria                        247.0
# Vestuário                                                   1454.0
# Vestuário Infantil                                           788.0
#
#                                               AREA   DENSIDADE
# NOME_SETOR
# Alimentação                            3359.343283   21.820242
# Arranjos e Complementos                 615.329088   32.028438
# Artes e Pintura                         713.705731    2.606116
# Bijouterias                            2165.445443   88.479383
# Calçados                               1881.447403   65.409968
# ...                                            ...         ...
# Decoração e Utilidades                 1033.677527   29.927868
# Esculturas                               47.580382    0.252205
# Mobilário, Flores, Arranjos, Cestaria   771.488214   14.012735
# Vestuário                              2591.442504  122.878561
# Vestuário Infantil                     1431.874390   66.590892
#
# [13 rows x 3 columns]

# %% [markdown]
# Note que os valores na coluna `'AREA'` correspondentes aos setores `'Criança'` e `'Vestuário Infantil'` são exatamente os mesmos calculados acima!

# %% [markdown]
# - Em essência, o `.groupby` opera da seguinte maneira:
# 1. **Divide** as linhas do `DataFrame` de acordo com a coluna especificada (no nosso exemplo, de acordo com o `'NOME_SETOR'`);
# 1. **Agrega** todas as outras linhas de acordo com a divisão feita, aplicando a função especificada (no nosso exemplo, `.sum`);
# 1. **Combina** os resultados obtidos dessa agregação em um novo `DataFrame`, indexado e classificado de acordo com a coluna escolhida (no nosso exemplo, `'NOME_SETOR'`).

# %%
afonso_pena.groupby('NOME_SETOR').sum()
# Out:
#                                        NUMERO_PRODUTOS_CADASTRADOS  \
# NOME_SETOR
# Alimentação                                                  733.0
# Arranjos e Complementos                                      379.0
# Artes e Pintura                                               62.0
# Bijouterias                                                 1047.0
# Calçados                                                     774.0
# ...                                                            ...
# Decoração e Utilidades                                       423.0
# Esculturas                                                     6.0
# Mobilário, Flores, Arranjos, Cestaria                        247.0
# Vestuário                                                   1454.0
# Vestuário Infantil                                           788.0
#
#                                               AREA   DENSIDADE
# NOME_SETOR
# Alimentação                            3359.343283   21.820242
# Arranjos e Complementos                 615.329088   32.028438
# Artes e Pintura                         713.705731    2.606116
# Bijouterias                            2165.445443   88.479383
# Calçados                               1881.447403   65.409968
# ...                                            ...         ...
# Decoração e Utilidades                 1033.677527   29.927868
# Esculturas                               47.580382    0.252205
# Mobilário, Flores, Arranjos, Cestaria   771.488214   14.012735
# Vestuário                              2591.442504  122.878561
# Vestuário Infantil                     1431.874390   66.590892
#
# [13 rows x 3 columns]

# %%
afonso_pena
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             F.F2.V016
# 84                             G.F3.V052
# 85                             E.F4.V003
# 86                             E.F2.V004
# 87                             D.F2.V016
# ...                                  ...
# 1350                           G.F4.V014
# 1351                           J.F1.V004
# 1352                           D.F4.V050
# 1353                           G.F2.V010
# 1354                           G.F1.V061
#
#                                                            NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              BARRACA CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  BARRACA CECÍLIA PAGANO NEVES SALAZAR
# 87                                      BARRACA CÉLIA APARECIDA DE SOUZA
# ...                                                                  ...
# 1350                                          BARRACA HELCIO LICIO SILVA
# 1351                                       BARRACA DIEGO DOS SANTOS DIAS
# 1352                                                 BARRACA JAIR CORREA
# 1353                               BARRACA SIDNEY FERNANDO KNEIPP SOARES
# 1354                                      BARRACA REGINA GARCIA FERREIRA
#
#                                                    NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  CECÍLIA PAGANO NEVES SALAZAR
# 87                                      CÉLIA APARECIDA DE SOUZA
# ...                                                          ...
# 1350                                          HELCIO LICIO SILVA
# 1351                                       DIEGO DOS SANTOS DIAS
# 1352                                                 JAIR CORREA
# 1353                               SIDNEY FERNANDO KNEIPP SOARES
# 1354                                      REGINA GARCIA FERREIRA
#
#                                                    NOME_PREPOSTO  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                           JANA FONSECA VIEIRA
# 84                                    KARINA RODRIGUES BRANDORFI
# 85                            BARBARA ISABELLE CARVALHO DE PAULA
# 86                                   GISELE PAGANO NEVES SALAZAR
# 87                                          EDSON PIRES DE SOUZA
# ...                                                          ...
# 1350                             GRAZIELA CRISTINA RAMALHO SILVA
# 1351                                     CELSO DE SOUZA LINHARES
# 1352                               Keli Aparecida Batista Correa
# 1353                                 ANA PAULA FAUSTINA DE SOUZA
# 1354                             Rejane Garcia Ferreira Clemente
#
#                                       NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                       Criança
# 84                                   Bijouterias
# 85                            Vestuário Infantil
# 86                            Vestuário Infantil
# 87                                     Vestuário
# ...                                          ...
# 1350                                 Bijouterias
# 1351                                    Calçados
# 1352                                   Vestuário
# 1353                                 Bijouterias
# 1354                                 Bijouterias
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# 84                                          BRINCO, ANEL, PULSEIRA, COLAR, ARCO
# 85                                                   VESTIDO, CONJUNTO, MACACÃO
# 86                                                    MACACÃO, BLUSA, SAPATINHO
# 87                            BLUSA, BERMUDA, ROUPA DE GINÁSTICA, SAIA, VEST...
# ...                                                                         ...
# 1350                          ANEL, COLAR, BROCHE, BRINCO, PULSEIRA, ALIANÇA...
# 1351                                              RASTEIRINHA, SAPATO, SANDÁLIA
# 1352                          VESTIDO DE MALHA, BATA DE TECIDO, CONJUNTO, SA...
# 1353                          COLAR, GARGANTILHA, ARCO, ANEL, PASSADOR DE CA...
# 1354                          COLAR DE METAL, PRESILHA, PASSADOR DE CABELO, ...
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                                    5.0  11.838911
# 84                                                    5.0  11.838911
# 85                                                    3.0  11.838911
# 86                                                    3.0  11.827592
# 87                                                    7.0  11.827592
# ...                                                   ...        ...
# 1350                                                  7.0  11.838911
# 1351                                                  3.0  11.827592
# 1352                                                  5.0  11.827592
# 1353                                                  7.0  11.838911
# 1354                                                  4.0  11.827592
#
#                               DENSIDADE
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             0.422336
# 84                             0.422336
# 85                             0.253402
# 86                             0.253644
# 87                             0.591836
# ...                                 ...
# 1350                           0.591271
# 1351                           0.253644
# 1352                           0.422740
# 1353                           0.591271
# 1354                           0.338192
#
# [1250 rows x 9 columns]

# %%
afonso_pena.groupby('NOME_SETOR').sum()
# Out:
#                                        NUMERO_PRODUTOS_CADASTRADOS  \
# NOME_SETOR
# Alimentação                                                  733.0
# Arranjos e Complementos                                      379.0
# Artes e Pintura                                               62.0
# Bijouterias                                                 1047.0
# Calçados                                                     774.0
# ...                                                            ...
# Decoração e Utilidades                                       423.0
# Esculturas                                                     6.0
# Mobilário, Flores, Arranjos, Cestaria                        247.0
# Vestuário                                                   1454.0
# Vestuário Infantil                                           788.0
#
#                                               AREA   DENSIDADE
# NOME_SETOR
# Alimentação                            3359.343283   21.820242
# Arranjos e Complementos                 615.329088   32.028438
# Artes e Pintura                         713.705731    2.606116
# Bijouterias                            2165.445443   88.479383
# Calçados                               1881.447403   65.409968
# ...                                            ...         ...
# Decoração e Utilidades                 1033.677527   29.927868
# Esculturas                               47.580382    0.252205
# Mobilário, Flores, Arranjos, Cestaria   771.488214   14.012735
# Vestuário                              2591.442504  122.878561
# Vestuário Infantil                     1431.874390   66.590892
#
# [13 rows x 3 columns]

# %% [markdown]
# ## Caveats do GroupBy

# %% [markdown]
# ### Colunas desaparecendo! ✨🐇🎩
#
# - O método de agregação que escolhemos para o `.groupby` é aplicado _a cada_ coluna do nosso DataFrame.
# - Quando essa operação não fizer sentido para uma determinada coluna, essa coluna desaparecerá!

# %% [markdown]
# No nosso exemplo, não podemos somar strings através do método `.sum`, então é por isso que colunas como `'NOME_FANTASIA'` desaparecem automaticamente após realizarmos o `.groupby`.

# %% [markdown]
# ### Cuidado com a função de agregação escolhida!
#
# - No `.groupby`, a função de agregação é aplicada a cada coluna **separadamente**.
# - Dependendo da função utilizada, as linhas do DataFrame resultante precisam ser interpretadas com cuidado!

# %% [markdown]
# No nosso exemplo, se quisermos saber a _densidade total_ ocupada por um setor, podemos ficar tentados a simplesmente utilizar um `.groupby` com a função de agregação `.sum`, e olhar para a coluna `'DENSIDADE'` no DataFrame resultante:

# %%
afonso_pena.groupby('NOME_SETOR').sum()
# Out:
#                                        NUMERO_PRODUTOS_CADASTRADOS  \
# NOME_SETOR
# Alimentação                                                  733.0
# Arranjos e Complementos                                      379.0
# Artes e Pintura                                               62.0
# Bijouterias                                                 1047.0
# Calçados                                                     774.0
# ...                                                            ...
# Decoração e Utilidades                                       423.0
# Esculturas                                                     6.0
# Mobilário, Flores, Arranjos, Cestaria                        247.0
# Vestuário                                                   1454.0
# Vestuário Infantil                                           788.0
#
#                                               AREA   DENSIDADE
# NOME_SETOR
# Alimentação                            3359.343283   21.820242
# Arranjos e Complementos                 615.329088   32.028438
# Artes e Pintura                         713.705731    2.606116
# Bijouterias                            2165.445443   88.479383
# Calçados                               1881.447403   65.409968
# ...                                            ...         ...
# Decoração e Utilidades                 1033.677527   29.927868
# Esculturas                               47.580382    0.252205
# Mobilário, Flores, Arranjos, Cestaria   771.488214   14.012735
# Vestuário                              2591.442504  122.878561
# Vestuário Infantil                     1431.874390   66.590892
#
# [13 rows x 3 columns]

# %% [markdown]
# Porém, como a densidade total na verdade seria dada por $\text{densidade total} = \text{número total de produtos}/\text{área total}$, esse resultado não está correto!

# %% [markdown]
# Por exemplo, para '`Vestuário Infantil`', a densidade total correta seria igual a:

# %%
afonso_pena[afonso_pena.get('NOME_SETOR') == 'Vestuário Infantil'].get('NUMERO_PRODUTOS_CADASTRADOS').sum()/afonso_pena[afonso_pena.get('NOME_SETOR') == 'Vestuário Infantil'].get('AREA').sum()
# Out:
# 0.5503276025371656

# %% [markdown]
# Por outro lado, a "densidade total" calculada através da soma das densidades no `.groupby` é igual a:

# %%
afonso_pena[afonso_pena.get('NOME_SETOR') == 'Vestuário Infantil'].get('DENSIDADE').sum()
# Out:
# 66.59089228766169

# %% [markdown]
# ## Mais exemplos de usos do GroupBy

# %% [markdown]
# ### Duas escolhas principais a serem feitas ao usar `.groupby`
#
# - Ao aplicarmos o `.groupby`, devemos sempre ter duas perguntas em mente:
# 1. Por qual coluna devemos agrupar?
# 2. Que método de agregação devemos usar?
#
# Veremos abaixo mais algumas aplicações do GroupBy com os dados da Feira da Afonso Pena.

# %% [markdown]
# #### Contando a quantidade de linhas de acordo com uma certa condição
#
# - Se quisermos saber o número de linhas de acordo com os valores de uma outra coluna, podemos aplicar o `.groupby` com a função de agregação `.size`.

# %% [markdown]
# Por exemplo, se quisermos saber o número de vendedores (lembre que cada linha do nosso DataFrame é um feirante) de acordo com cada setor de vendas, podemos fazer:

# %%
afonso_pena.groupby('NOME_SETOR').size()
# Out:
# NOME_SETOR
# Alimentação                              100
# Arranjos e Complementos                   52
# Artes e Pintura                           30
# Bijouterias                              183
# Calçados                                 159
#                                         ...
# Decoração e Utilidades                    69
# Esculturas                                 2
# Mobilário, Flores, Arranjos, Cestaria     42
# Vestuário                                219
# Vestuário Infantil                       121
# Length: 13, dtype: int64

# %% [markdown]
# Podemos também utilizar o método `.count` para responder a mesma pergunta acima.
#
# A diferença é que com `.count` a saída em geral é mais completa do que precisamos, mostrando o número de _observações_ disponíveis em cada coluna.
#
# Como no nosso exemplo todas as linhas têm todas as observações completas, com `.count` os mesmos números resultantes de `.size` simplesmente se repetem à cada coluna:

# %%
afonso_pena.groupby('NOME_SETOR').count()
# Out:
#                                        CODIGO_VAGA  NOME_FANTASIA  \
# NOME_SETOR
# Alimentação                                    100            100
# Arranjos e Complementos                         52             52
# Artes e Pintura                                 30             30
# Bijouterias                                    183            183
# Calçados                                       159            159
# ...                                            ...            ...
# Decoração e Utilidades                          69             69
# Esculturas                                       2              2
# Mobilário, Flores, Arranjos, Cestaria           42             42
# Vestuário                                      219            219
# Vestuário Infantil                             121            121
#
#                                        NOME_FEIRANTE  NOME_PREPOSTO  PRODUTOS  \
# NOME_SETOR
# Alimentação                                      100            100       100
# Arranjos e Complementos                           52             52        52
# Artes e Pintura                                   30             30        30
# Bijouterias                                      183            183       183
# Calçados                                         159            159       159
# ...                                              ...            ...       ...
# Decoração e Utilidades                            69             69        69
# Esculturas                                         2              2         2
# Mobilário, Flores, Arranjos, Cestaria             42             42        42
# Vestuário                                        219            219       219
# Vestuário Infantil                               121            121       121
#
#                                        NUMERO_PRODUTOS_CADASTRADOS  AREA  \
# NOME_SETOR
# Alimentação                                                    100   100
# Arranjos e Complementos                                         52    52
# Artes e Pintura                                                 30    30
# Bijouterias                                                    183   183
# Calçados                                                       159   159
# ...                                                            ...   ...
# Decoração e Utilidades                                          69    69
# Esculturas                                                       2     2
# Mobilário, Flores, Arranjos, Cestaria                           42    42
# Vestuário                                                      219   219
# Vestuário Infantil                                             121   121
#
#                                        DENSIDADE
# NOME_SETOR
# Alimentação                                  100
# Arranjos e Complementos                       52
# Artes e Pintura                               30
# Bijouterias                                  183
# Calçados                                     159
# ...                                          ...
# Decoração e Utilidades                        69
# Esculturas                                     2
# Mobilário, Flores, Arranjos, Cestaria         42
# Vestuário                                    219
# Vestuário Infantil                           121
#
# [13 rows x 8 columns]

# %% [markdown]
# #### Estatísticas descritivas
#
# Podemos também utilizar como funções de agregação as funções de estatísticas descritivas básicas, tais como `.mean`, `.min`, `.max` e `.median`.

# %%
afonso_pena.groupby('NOME_SETOR').mean()
# Out:
#                                        NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# NOME_SETOR
# Alimentação                                               7.330000  33.593433
# Arranjos e Complementos                                   7.288462  11.833252
# Artes e Pintura                                           2.066667  23.790191
# Bijouterias                                               5.721311  11.833035
# Calçados                                                  4.867925  11.833003
# ...                                                            ...        ...
# Decoração e Utilidades                                    6.130435  14.980834
# Esculturas                                                3.000000  23.790191
# Mobilário, Flores, Arranjos, Cestaria                     5.880952  18.368767
# Vestuário                                                 6.639269  11.833071
# Vestuário Infantil                                        6.512397  11.833673
#
#                                        DENSIDADE
# NOME_SETOR
# Alimentação                             0.218202
# Arranjos e Complementos                 0.615931
# Artes e Pintura                         0.086871
# Bijouterias                             0.483494
# Calçados                                0.411383
# ...                                          ...
# Decoração e Utilidades                  0.433737
# Esculturas                              0.126102
# Mobilário, Flores, Arranjos, Cestaria   0.333637
# Vestuário                               0.561089
# Vestuário Infantil                      0.550338
#
# [13 rows x 3 columns]

# %%
afonso_pena.groupby('NOME_SETOR').min()
# Out:
#                                       CODIGO_VAGA  \
# NOME_SETOR
# Alimentação                             X.F1.V001
# Arranjos e Complementos                 H.F1.V001
# Artes e Pintura                         P.F1.V001
# Bijouterias                             G.F1.V001
# Calçados                                J.F1.V001
# ...                                           ...
# Decoração e Utilidades                  B.F1.V001
# Esculturas                              S.F1.V002
# Mobilário, Flores, Arranjos, Cestaria   A.F1.V001
# Vestuário                               D.F1.V001
# Vestuário Infantil                      E.F1.V001
#
#                                                                     NOME_FANTASIA  \
# NOME_SETOR
# Alimentação                                     BARRACA ADVALD MARTINS DOS SANTOS
# Arranjos e Complementos                           BARRACA ADILMO DE PAIVA VICENTE
# Artes e Pintura                                     BARRACA ACIOLI ALVES DE JESUS
# Bijouterias                                          BARRACA ADALGISA COSTA COUTO
# Calçados                                    BARRACA ABÍLIO CESAR FIGUEIREDO FILHO
# ...                                                                           ...
# Decoração e Utilidades                            BARRACA ACYLENE COIMBRA E SILVA
# Esculturas                              BARRACA JACQUELINE DIAS DOS SANTOS VICTOR
# Mobilário, Flores, Arranjos, Cestaria  BARRACA AGDA DE CÁSSIA MARIA PEREIRA DAIAN
# Vestuário                                BARRACA ADALBERTO FERRAZ DE PAULA DANTAS
# Vestuário Infantil                            BARRACA ADRIANA PINHEIRO DOS SANTOS
#
#                                                             NOME_FEIRANTE  \
# NOME_SETOR
# Alimentação                                     ADVALD MARTINS DOS SANTOS
# Arranjos e Complementos                           ADILMO DE PAIVA VICENTE
# Artes e Pintura                                     ACIOLI ALVES DE JESUS
# Bijouterias                                          ADALGISA COSTA COUTO
# Calçados                                    ABÍLIO CESAR FIGUEIREDO FILHO
# ...                                                                   ...
# Decoração e Utilidades                            ACYLENE COIMBRA E SILVA
# Esculturas                              JACQUELINE DIAS DOS SANTOS VICTOR
# Mobilário, Flores, Arranjos, Cestaria  AGDA DE CÁSSIA MARIA PEREIRA DAIAN
# Vestuário                                ADALBERTO FERRAZ DE PAULA DANTAS
# Vestuário Infantil                            ADRIANA PINHEIRO DOS SANTOS
#
#                                                           NOME_PREPOSTO  \
# NOME_SETOR
# Alimentação                               ADAIR DE JESUS FERREIRA BRITO
# Arranjos e Complementos                         ADEIZA DE PAIVA VICENTE
# Artes e Pintura                                   ADELIA GONÇALVES DIAS
# Bijouterias                            ADRIANA DELGADO MORAIS ABURACHID
# Calçados                                       ABIGAIL BARBOSA MEDEIROS
# ...                                                                 ...
# Decoração e Utilidades                    ADRIANA CRISTINA SILVA SANTOS
# Esculturas                                        EULER FERREIRA VICTOR
# Mobilário, Flores, Arranjos, Cestaria               ADAO SOARES PEREIRA
# Vestuário                                        ADALIA DE SOUZA AMORIM
# Vestuário Infantil                                 AGDA GIOVANNA VILELA
#
#                                                                                 PRODUTOS  \
# NOME_SETOR
# Alimentação                                                                      ACARAJÉ
# Arranjos e Complementos                    ANEL, ARCO, BRINCO, PASSADOR, COLAR, PULSEIRA
# Artes e Pintura                                                DESENHO, PINTURA ACRÍLICA
# Bijouterias                                          ANEL, ARCO, PULSEIRA, COLAR, BRINCO
# Calçados                                     BOLSA DE LONA, CHINELO, SANDÁLIA, SAPATILHA
# ...                                                                                  ...
# Decoração e Utilidades                                      ABAJOUR, CACHEPOT, LUMINÁRIA
# Esculturas                                             ORNAMENTOS DECORATIVOS, ESCULTURA
# Mobilário, Flores, Arranjos, Cestaria  ARRANJO DE  FLOR EMBORRACHADA, FLOR DE TECIDO,...
# Vestuário                              BATA, PARCA, CANGA, SAÍDA DE PRAIA, SAIA, BLUS...
# Vestuário Infantil                     BABA OMBRO, CASACO, PAGÃO, CALÇA, TOUCA, SAPAT...
#
#                                        NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# NOME_SETOR
# Alimentação                                                    1.0  33.462435
# Arranjos e Complementos                                        2.0  11.827592
# Artes e Pintura                                                1.0  23.790191
# Bijouterias                                                    2.0  11.827592
# Calçados                                                       1.0  11.827592
# ...                                                            ...        ...
# Decoração e Utilidades                                         1.0  11.827592
# Esculturas                                                     2.0  23.790191
# Mobilário, Flores, Arranjos, Cestaria                          1.0  11.827592
# Vestuário                                                      1.0  11.827592
# Vestuário Infantil                                             1.0  11.827592
#
#                                        DENSIDADE
# NOME_SETOR
# Alimentação                             0.029676
# Arranjos e Complementos                 0.168934
# Artes e Pintura                         0.042034
# Bijouterias                             0.168934
# Calçados                                0.084548
# ...                                          ...
# Decoração e Utilidades                  0.084467
# Esculturas                              0.084068
# Mobilário, Flores, Arranjos, Cestaria   0.047157
# Vestuário                               0.084467
# Vestuário Infantil                      0.084467
#
# [13 rows x 8 columns]

# %%
afonso_pena.groupby('NOME_SETOR').median()
# Out:
#                                        NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# NOME_SETOR
# Alimentação                                                    7.0  33.595966
# Arranjos e Complementos                                        7.5  11.833252
# Artes e Pintura                                                2.0  23.790191
# Bijouterias                                                    6.0  11.827592
# Calçados                                                       5.0  11.827592
# ...                                                            ...        ...
# Decoração e Utilidades                                         5.0  11.838911
# Esculturas                                                     3.0  23.790191
# Mobilário, Flores, Arranjos, Cestaria                          6.0  21.205709
# Vestuário                                                      7.0  11.827592
# Vestuário Infantil                                             6.0  11.838911
#
#                                        DENSIDADE
# NOME_SETOR
# Alimentação                             0.208372
# Arranjos e Complementos                 0.633787
# Artes e Pintura                         0.084068
# Bijouterias                             0.506803
# Calçados                                0.422740
# ...                                          ...
# Decoração e Utilidades                  0.338192
# Esculturas                              0.126102
# Mobilário, Flores, Arranjos, Cestaria   0.329097
# Vestuário                               0.591271
# Vestuário Infantil                      0.506803
#
# [13 rows x 3 columns]

# %%
afonso_pena.groupby('NOME_SETOR').max()
# Out:
#                                       CODIGO_VAGA  \
# NOME_SETOR
# Alimentação                             Z.F4.V004
# Arranjos e Complementos                 H.F2.V032
# Artes e Pintura                         P.F2.V011
# Bijouterias                             G.F4.V059
# Calçados                                J.F4.V046
# ...                                           ...
# Decoração e Utilidades                  B.F4.V021
# Esculturas                              S.F1.V003
# Mobilário, Flores, Arranjos, Cestaria   A.F4.V019
# Vestuário                               D.F4.V062
# Vestuário Infantil                      E.F4.V033
#
#                                                                       NOME_FANTASIA  \
# NOME_SETOR
# Alimentação                                        BARRACA ZULMA CONCEIÇÃO DE SOUZA
# Arranjos e Complementos                                  BARRACA WAULENO LUIS DE SA
# Artes e Pintura                                       BARRACA WILSON BRAGA HENRIQUE
# Bijouterias                                            BARRACA ÍRIS COSTA GUIMARÃES
# Calçados                                              BARRACA ZOLMA RODRIGUES LEITE
# ...                                                                             ...
# Decoração e Utilidades                           BARRACA ZÉLIA MAGALHÃES DE ANDRADE
# Esculturas                                       BARRACA JOSÉ RODRIGUES EVANGELISTA
# Mobilário, Flores, Arranjos, Cestaria              BARRACA WALLACE GROSSI GONÇALVES
# Vestuário                                         BARRACA ZILDA MOREIRA DE OLIVEIRA
# Vestuário Infantil                     BARRACA ÂNGELA ANATOLIA DE OLIVEIRA SALDANHA
#
#                                                               NOME_FEIRANTE  \
# NOME_SETOR
# Alimentação                                        ZULMA CONCEIÇÃO DE SOUZA
# Arranjos e Complementos                                  WAULENO LUIS DE SA
# Artes e Pintura                                       WILSON BRAGA HENRIQUE
# Bijouterias                                            ÍRIS COSTA GUIMARÃES
# Calçados                                              ZOLMA RODRIGUES LEITE
# ...                                                                     ...
# Decoração e Utilidades                           ZÉLIA MAGALHÃES DE ANDRADE
# Esculturas                                       JOSÉ RODRIGUES EVANGELISTA
# Mobilário, Flores, Arranjos, Cestaria              WALLACE GROSSI GONÇALVES
# Vestuário                                         ZILDA MOREIRA DE OLIVEIRA
# Vestuário Infantil                     ÂNGELA ANATOLIA DE OLIVEIRA SALDANHA
#
#                                                         NOME_PREPOSTO  \
# NOME_SETOR
# Alimentação                                WELLINGTON RODRIGUES ALVES
# Arranjos e Complementos                    WANESSA DE FREITAS MARIANO
# Artes e Pintura                        VALDEMIR NASCIMENTO DOS SANTOS
# Bijouterias                                   ÉRICA DE FREITAS LUCENA
# Calçados                                          WEBERT CARLOS ALVES
# ...                                                               ...
# Decoração e Utilidades                        ZENAIDE SILVA DAS DORES
# Esculturas                                WARLEY PINHEIRO EVANGELISTA
# Mobilário, Flores, Arranjos, Cestaria    SONIA MARCIA SOUZA ALEXANDRE
# Vestuário                              ÍSIS DE FREITAS ESPECHIT BRAGA
# Vestuário Infantil                               WANDA LUCIA DE SOUZA
#
#                                                                                 PRODUTOS  \
# NOME_SETOR
# Alimentação                            ÁGUA MINERAL, REFRIGERANTE, CHOPP, ÁGUA DE COC...
# Arranjos e Complementos                TURBANTE, TIARA, FAIXA, PASSADOR, CHAPÉU DE CR...
# Artes e Pintura                                                   QUADRO, PINTURA A ÓLEO
# Bijouterias                            TERÇO, PULSEIRA, BRINCO, MEDALHÃO, BROCHE, ARC...
# Calçados                                 TÊNIS, SAPATILHA, TÊNIS, RASTEIRINHA, SAPATILHA
# ...                                                                                  ...
# Decoração e Utilidades                 ÁRVORE DE PEDRA, INCENSÁRIO, CHAVEIRO, IMAGENS...
# Esculturas                                  QUADRO, QUADRO, PLACAS EM MADEIRA, ESCULTURA
# Mobilário, Flores, Arranjos, Cestaria  TAMBORETE, BANCO, PORTA RETRATO, CINZEIRO, CAB...
# Vestuário                              VESTIDO, TOUCA, CACHECOL DE TRICÔ, CACHECOL DE...
# Vestuário Infantil                     VESTIDO, VESTIDO TEMÁTICO, CALCINHA, FOFOQUINH...
#
#                                        NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# NOME_SETOR
# Alimentação                                                   21.0  33.697508
# Arranjos e Complementos                                       12.0  11.838911
# Artes e Pintura                                                5.0  23.790191
# Bijouterias                                                   13.0  11.838911
# Calçados                                                      11.0  11.838911
# ...                                                            ...        ...
# Decoração e Utilidades                                        20.0  21.292159
# Esculturas                                                     4.0  23.790191
# Mobilário, Flores, Arranjos, Cestaria                         16.0  21.270342
# Vestuário                                                     12.0  11.838911
# Vestuário Infantil                                            16.0  11.838911
#
#                                        DENSIDADE
# NOME_SETOR
# Alimentação                             0.624794
# Arranjos e Complementos                 1.014577
# Artes e Pintura                         0.210171
# Bijouterias                             1.098074
# Calçados                                0.929140
# ...                                          ...
# Decoração e Utilidades                  1.183673
# Esculturas                              0.168137
# Mobilário, Flores, Arranjos, Cestaria   0.754514
# Vestuário                               1.014577
# Vestuário Infantil                      1.352769
#
# [13 rows x 8 columns]

# %% [markdown]
# Note que os operadores `.min` e `.max` nesse caso podem ser utilizados para strings, retornando, respectivamente, o _primeiro_ e _último_ elementos de cada coluna em ordem alfabética.

# %% [markdown]
# #### Usando `.sum()` em um array/série booleana
#
# - Um fato muito útil em algumas ocasiões é que a _soma_ de um array/série booleana fornece uma contagem do número de elementos iguais a `True`.
# - Isso ocorre porque o Python trata `True` como `1` e `False` como `0`.

# %%
True == 1
# Out:
# True

# %%
False == 0
# Out:
# True

# %% [markdown]
# Suponha que estejamos interessados em encontrar o número total, por setor, dos vendedores com mais de 12 produtos cadastrados.

# %% [markdown]
# Primeiramente, criamos um DataFrame com uma coluna a mais ('`MAIS_DE_12`'), refletindo essa condição:

# %%
bool_df = afonso_pena.assign(MAIS_DE_12 = afonso_pena.get('NUMERO_PRODUTOS_CADASTRADOS') >= 12)
bool_df
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             F.F2.V016
# 84                             G.F3.V052
# 85                             E.F4.V003
# 86                             E.F2.V004
# 87                             D.F2.V016
# ...                                  ...
# 1350                           G.F4.V014
# 1351                           J.F1.V004
# 1352                           D.F4.V050
# 1353                           G.F2.V010
# 1354                           G.F1.V061
#
#                                                            NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              BARRACA CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  BARRACA CECÍLIA PAGANO NEVES SALAZAR
# 87                                      BARRACA CÉLIA APARECIDA DE SOUZA
# ...                                                                  ...
# 1350                                          BARRACA HELCIO LICIO SILVA
# 1351                                       BARRACA DIEGO DOS SANTOS DIAS
# 1352                                                 BARRACA JAIR CORREA
# 1353                               BARRACA SIDNEY FERNANDO KNEIPP SOARES
# 1354                                      BARRACA REGINA GARCIA FERREIRA
#
#                                                    NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  CECÍLIA PAGANO NEVES SALAZAR
# 87                                      CÉLIA APARECIDA DE SOUZA
# ...                                                          ...
# 1350                                          HELCIO LICIO SILVA
# 1351                                       DIEGO DOS SANTOS DIAS
# 1352                                                 JAIR CORREA
# 1353                               SIDNEY FERNANDO KNEIPP SOARES
# 1354                                      REGINA GARCIA FERREIRA
#
#                                                    NOME_PREPOSTO  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                           JANA FONSECA VIEIRA
# 84                                    KARINA RODRIGUES BRANDORFI
# 85                            BARBARA ISABELLE CARVALHO DE PAULA
# 86                                   GISELE PAGANO NEVES SALAZAR
# 87                                          EDSON PIRES DE SOUZA
# ...                                                          ...
# 1350                             GRAZIELA CRISTINA RAMALHO SILVA
# 1351                                     CELSO DE SOUZA LINHARES
# 1352                               Keli Aparecida Batista Correa
# 1353                                 ANA PAULA FAUSTINA DE SOUZA
# 1354                             Rejane Garcia Ferreira Clemente
#
#                                       NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                       Criança
# 84                                   Bijouterias
# 85                            Vestuário Infantil
# 86                            Vestuário Infantil
# 87                                     Vestuário
# ...                                          ...
# 1350                                 Bijouterias
# 1351                                    Calçados
# 1352                                   Vestuário
# 1353                                 Bijouterias
# 1354                                 Bijouterias
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# 84                                          BRINCO, ANEL, PULSEIRA, COLAR, ARCO
# 85                                                   VESTIDO, CONJUNTO, MACACÃO
# 86                                                    MACACÃO, BLUSA, SAPATINHO
# 87                            BLUSA, BERMUDA, ROUPA DE GINÁSTICA, SAIA, VEST...
# ...                                                                         ...
# 1350                          ANEL, COLAR, BROCHE, BRINCO, PULSEIRA, ALIANÇA...
# 1351                                              RASTEIRINHA, SAPATO, SANDÁLIA
# 1352                          VESTIDO DE MALHA, BATA DE TECIDO, CONJUNTO, SA...
# 1353                          COLAR, GARGANTILHA, ARCO, ANEL, PASSADOR DE CA...
# 1354                          COLAR DE METAL, PRESILHA, PASSADOR DE CABELO, ...
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                                    5.0  11.838911
# 84                                                    5.0  11.838911
# 85                                                    3.0  11.838911
# 86                                                    3.0  11.827592
# 87                                                    7.0  11.827592
# ...                                                   ...        ...
# 1350                                                  7.0  11.838911
# 1351                                                  3.0  11.827592
# 1352                                                  5.0  11.827592
# 1353                                                  7.0  11.838911
# 1354                                                  4.0  11.827592
#
#                               DENSIDADE  MAIS_DE_12
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             0.422336       False
# 84                             0.422336       False
# 85                             0.253402       False
# 86                             0.253644       False
# 87                             0.591836       False
# ...                                 ...         ...
# 1350                           0.591271       False
# 1351                           0.253644       False
# 1352                           0.422740       False
# 1353                           0.591271       False
# 1354                           0.338192       False
#
# [1250 rows x 10 columns]

# %% [markdown]
# Após criar a coluna das booleanas com a nossa condição, é só realizar o GroupBy, agregando com `.sum` por 'NOME_SETOR':

# %%
bool_df.groupby('NOME_SETOR').sum()
# Out:
#                                        NUMERO_PRODUTOS_CADASTRADOS  \
# NOME_SETOR
# Alimentação                                                  733.0
# Arranjos e Complementos                                      379.0
# Artes e Pintura                                               62.0
# Bijouterias                                                 1047.0
# Calçados                                                     774.0
# ...                                                            ...
# Decoração e Utilidades                                       423.0
# Esculturas                                                     6.0
# Mobilário, Flores, Arranjos, Cestaria                        247.0
# Vestuário                                                   1454.0
# Vestuário Infantil                                           788.0
#
#                                               AREA   DENSIDADE  MAIS_DE_12
# NOME_SETOR
# Alimentação                            3359.343283   21.820242          14
# Arranjos e Complementos                 615.329088   32.028438           1
# Artes e Pintura                         713.705731    2.606116           0
# Bijouterias                            2165.445443   88.479383           1
# Calçados                               1881.447403   65.409968           0
# ...                                            ...         ...         ...
# Decoração e Utilidades                 1033.677527   29.927868           4
# Esculturas                               47.580382    0.252205           0
# Mobilário, Flores, Arranjos, Cestaria   771.488214   14.012735           2
# Vestuário                              2591.442504  122.878561           4
# Vestuário Infantil                     1431.874390   66.590892          10
#
# [13 rows x 4 columns]

# %% [markdown]
# Note que os valores contidos na coluna 'MAIS_DE_12' acima são bem diferentes do que temos quando agregamos por 'NOME_SETOR' e simplesmente utilizamos `.size`, como fizemos anteriormente:

# %%
bool_df.groupby('NOME_SETOR').size()
# Out:
# NOME_SETOR
# Alimentação                              100
# Arranjos e Complementos                   52
# Artes e Pintura                           30
# Bijouterias                              183
# Calçados                                 159
#                                         ...
# Decoração e Utilidades                    69
# Esculturas                                 2
# Mobilário, Flores, Arranjos, Cestaria     42
# Vestuário                                219
# Vestuário Infantil                       121
# Length: 13, dtype: int64

# %% [markdown]
# ## Resumo
#
# - Podemos escrever consultas que envolvam múltiplas condições, desde que:
#     - Coloquemos parênteses em todas as condições.
#     - Separemos as condições utilizando `&` (se você precisar que todas sejam verdadeiras), ou utilizando `|` (se você precisar que pelo menos uma seja verdadeira).
# - O método `df.groupby(column_name).agg_method()` nos permite **agregar** todas as linhas de um DataFrame `df` em uma única linha em um novo DataFrame, desde que essas linhas tenham o mesmo valor na coluna `column_name`.
#     - As múltiplas linhas são agregadas pelo `.groupby` utilizando um método de agregação `agg_method()` para combinar os diferentes valores.
#     - Métodos de agregação comuns incluem `.size`, `.count()`, `.sum()`, `.mean()`, `.median()`, `.max()` e `.min()`.
